# %%
import pandas as pd #used for data manipulation
import numpy as np #used for numerical analysis
from collections import Counter as c # return counts of number of classess
import matplotlib.pyplot as plt #used for data visualization
import seaborn as sns #data visualization library
import missingno as msno
from sklearn.metrics import accuracy_score, confusion_matrix#model performance
from sklearn.model_selection import train_test_split #splits data in random train and test array
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
import pickle

# %%
data = pd.read_csv("kidney_disease.csv") #loading the csv data

# %%
data.head() #return you the first 5 row values
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
from pandas.core.internals.base import Index
data.columns #return all the column names
Index(['age','bp','sg','al','su','rbc','pc','pcc','ba','bgr','bu','sc','sod','pot','hemo','pcv','wc','rc','htn','dm','cad','appet','pe','ane','classification'],dtype='object')
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
data.isnull().any()
# Out:
# id                False
# age                True
# bp                 True
# sg                 True
# al                 True
# su                 True
# rbc                True
# pc                 True
# pcc                True
# ba                 True
# bgr                True
# bu                 True
# sc                 True
# sod                True
# pot                True
# hemo               True
# pcv                True
# wc                 True
# rc                 True
# htn                True
# dm                 True
# cad                True
# appet              True
# pe                 True
# ane                True
# classification    False
# dtype: bool

# %%
catcols=set(data.dtypes[data.dtypes=='o'].index.values)
print(catcols)
# Out:
# set()

# %%
for i in catcols:
    print("Columns",i)
    print(c(data[i]))
    print('*'*120+'\n')

# %%
#'specific_gravity','albumin','suger',(as these columns are numerical it is removed)
catcols=['ane','pe','appet','ba','classification','cad','dm','htn','pc','pcc','rbc']

# %%
from sklearn.preprocessing import LabelEncoder
for i in catcols:
  print("LABEL ENCODING OF:",i)
  LEi=LabelEncoder()
  print(c(data[i]))
  data[i]=LEi.fit_transform(data[i])
  print(c(data[i]))
  print("*"*100)
# Out:
# LABEL ENCODING OF: ane
# Counter({'no': 339, 'yes': 60, nan: 1})
# Counter({0: 339, 1: 60, 2: 1})
# ****************************************************************************************************
# LABEL ENCODING OF: pe
# Counter({'no': 323, 'yes': 76, nan: 1})
# Counter({0: 323, 1: 76, 2: 1})
# ****************************************************************************************************
# LABEL ENCODING OF: appet
# Counter({'good': 317, 'poor': 82, nan: 1})
# Counter({0: 317, 1: 82, 2: 1})
# ****************************************************************************************************
# LABEL ENCODING OF: ba
# Counter({'notpresent': 374, 'present': 22, nan: 4})
# Counter({0: 374, 1: 22, 2: 4})
# ****************************************************************************************************
# LABEL ENCODING OF: classification
# Counter({'ckd': 248, 'notckd': 150, 'ckd\t': 2})
# Counter({0: 248, 2: 150, 1: 2})
# ...

# %%
data.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               rbc          pc         pcc          ba  ...         sod  \
# count  400.000000  400.000000  400.000000  400.000000  ...  313.000000
# mean     1.262500    0.972500    0.125000    0.075000  ...  137.528754
# ...

# %%
sns.displot(data.age)

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(5,5))
plt.scatter(data['age'],data['bp'],color='blue')
plt.xlable('age')
plt.ylable('bp')
plt.title("age VS blood scatter plot")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-be02423d0b74> in <cell line: 4>()
#       2 fig=plt.figure(figsize=(5,5))
#       3 plt.scatter(data['age'],data['bp'],color='blue')
# ----> 4 plt.xlable('age')
#       5 plt.ylable('bp')
#       6 plt.title("age VS blood scatter plot")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
f,ax=plt.subplots(figsize=(18,10))
sns.heatmap(data.corr(),annot=True,fmt=".2f",ax=ax,linewidths=0.5,linecolor="orange")
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()
# Out:
# <ipython-input-47-e8d9004f5c7e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,fmt=".2f",ax=ax,linewidths=0.5,linecolor="orange")

# %%
sns.countplot(data['classification'])
# Out:
# <Axes: ylabel='count'>

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_bal=sc.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-8e2ac7b0f53f> in <cell line: 3>()
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc=StandardScaler()
# ----> 3 x_bal=sc.fit_transform(x)
#
# NameError: name 'x' is not defined

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-750fe2717862> in <cell line: 2>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
#
# NameError: name 'x' is not defined

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
from threading import activeCount
classification = Sequential()
classification.add(Dense(30,activeCount))
classification.add(Dense(128,activation='relu'))
classification.add(Dense(64,activation='relu'))
classification.add(Dense(32,activation='relu'))
classification.add(Dense(1,activation='sigmoid'))

# %%
from sklearn import metrics
classification.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
classification.fit(x_train,y_train,batch_size=10,validation_split=0.2,epochs=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-dbb8d9275ccc> in <cell line: 1>()
# ----> 1 classification.fit(x_train,y_train,batch_size=10,validation_split=0.2,epochs=100)
#
# NameError: name 'x_train' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=10,criterion='entropy')

# %%
rfc.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-b87bb2ba9825> in <cell line: 1>()
# ----> 1 rfc.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
y_predict = rfc.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-f84558932bd8> in <cell line: 1>()
# ----> 1 y_predict = rfc.predict(x_test)
#
# NameError: name 'x_test' is not defined

# %%
from sklearn.linear_model import Logis
